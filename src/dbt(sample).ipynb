# %%
df = spark.read \
.format("csv") \
.option("header",True) \
.option("inferSchema",True) \
.load("/Volumes/workspace/default/dbt/sales_dbt.csv")

df.write \
.format("delta") \
.mode("overwrite") \
.saveAsTable("dbt_bronze_sales")

# %%
# %sql
SELECT * FROM dbt_bronze_sales;
