# %% [markdown]
# FAKER

# %%
# %pip install faker

# %%
dbutils.library.restartPython()

# %%
from faker import Faker

fake = Faker()

for i in range(5):
    print(fake.name())

# %% [markdown]
# PLOTLY

# %%
import plotly.express as px

data = {
    "city": ["Chennai","Bangalore","Delhi"],
    "sales": [200,350,150]
}

fig = px.bar(data, x="city", y="sales")
fig.show()
