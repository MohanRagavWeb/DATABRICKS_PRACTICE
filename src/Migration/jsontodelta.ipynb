# %%
df = spark.read.format("json") \
    .load("/Volumes/workspace/default/my_volume_1/customer.json")

display(df)

# %%
df.write.format("delta") \
    .mode("overwrite") \
    .save("/Volumes/workspace/default/my_volume_2/json_to_delta")
