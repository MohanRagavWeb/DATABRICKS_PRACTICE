# %%
print("Notebook C started")

data = [(1,"Laptop",50000),(2,"Phone",20000)]

columns = ["id","product","price"]

df = spark.createDataFrame(data,columns)

display(df)

print("Notebook C finished")
dbutils.notebook.exit("DataFrame created successfully")
