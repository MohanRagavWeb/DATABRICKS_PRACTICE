# %%
print("Notebook A started")

dbutils.notebook.run(
"/Workspace/Users/mohan.r@diggibyte.com/DATABRICKS_PRACTICE/src/Calling_NoteBooks/Notebook_B",
60
)
result = dbutils.notebook.run("/Workspace/Users/mohan.r@diggibyte.com/DATABRICKS_PRACTICE/src/Calling_NoteBooks/Notebook_C",60)

print(result)
print("Notebook A finished")
