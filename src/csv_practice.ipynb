# %% [markdown]
# DISPLAY CSV

# %%
df = spark.table("workspace.default.sales_data")

display(df)

# %% [markdown]
# Verify Schema

# %%
df.printSchema()

# %% [markdown]
# Basic Transformations

# %%
df.filter(df.price > 10000).show()

# %% [markdown]
# Add new column

# %%
from pyspark.sql.functions import col

df = df.withColumn("total_amount", col("price") * col("quantity"))

display(df)
