# %% [markdown]
# | Old Method              | New Method           |
# |------------------------|----------------------|
# | dbutils.library        | %pip install         |
# | Cluster library install| %pip install         |
# | restartPython()        | automatic restart    |

# %% [markdown]
# Install a library

# %%
# %pip install faker

# %% [markdown]
# Check installed libraries

# %%
# %pip list

# %% [markdown]
# Upgrade a library

# %%
# %pip install --upgrade faker

# %% [markdown]
# Uninstall a library

# %%
# %pip uninstall faker

# %% [markdown]
# Example Practice

# %%
# %pip install faker

# %%
from faker import Faker

fake = Faker()

print(fake.name())
print(fake.email())
print(fake.city())
