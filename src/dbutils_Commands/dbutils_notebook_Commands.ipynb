# %% [markdown]
# 1️⃣ Running Another Notebook

# %%
dbutils.notebook.run("/Workspace/Users/mohan.r@diggibyte.com/DATABRICKS_PRACTICE/src/dbutils_Commands/practice_files/notebook_A",60)

# %% [markdown]
# 2️⃣ Passing Parameters to Notebook

# %%
dbutils.notebook.run("/Workspace/Users/mohan.r@diggibyte.com/DATABRICKS_PRACTICE/src/dbutils_Commands/practice_files/notebook_A",60,{"name":"mohan"})

# %% [markdown]
# Getting Parameters

# %%
dbutils.widgets.text("name","mohan")
file = dbutils.widgets.get("name")

print(file)

# %% [markdown]
# 3️⃣ Returning Values from Notebook

# %%
dbutils.notebook.exit("message")

# %% [markdown]
# Checking Notebook Utilities Help

# %%
dbutils.notebook.help()
