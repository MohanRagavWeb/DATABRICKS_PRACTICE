# %%
data=[(1,"mohan"),(2,"suresh")]

df= spark.createDataFrame(data,["id","name"])
display(df)
dbutils.notebook.exit("message from notebook1")

# %% [markdown]
# Getting Parameters

# %%
dbutils.widgets.text("name","mohan")
file = dbutils.widgets.get("name")

print(file)
