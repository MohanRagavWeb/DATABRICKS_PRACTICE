# %%
print("Starting pipeline")

result = dbutils.notebook.run(
    "/Workspace/Users/mohan.r@diggibyte.com/DATABRICKS_PRACTICE/src/dbutils_Commands/notebook_b",
    60,
    {"file_name": "sales.csv"}
)

print("Result from Notebook_B:", result)
