# %%
# %sql
INSERT INTO students_delta
VALUES (11, 'Mohan', 25, 'M', 'CSE', 96, 'Bangalore');

# %%
# %sql
update students_delta
set marks=100 
where name='Meena'

# %%
# %sql
MERGE INTO employees_delta AS target
USING new_employees AS source
ON target.id = source.id
WHEN MATCHED THEN
  UPDATE SET target.salary = source.salary
WHEN NOT MATCHED THEN
  INSERT *

# %%
# %sql
SELECT * FROM students_delta VERSION AS OF 0;

# %%
# %sql
VACUUM students_delta;

--Used to remove old unused files from the Delta table to free storage

# %%
# %sql
select * from students_delta
