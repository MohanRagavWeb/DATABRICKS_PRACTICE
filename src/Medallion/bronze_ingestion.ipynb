# %% [markdown]
# /Volumes/workspace/default/my_volume_1/medallion/medallion_data.csv

# %% [markdown]
# Bronze Layer (Raw Data Ingestion)

# %%
# read raw csv from volume
df = spark.read.csv(
"/Volumes/workspace/default/my_volume_1/medallion/medallion_data.csv",
header=True,
inferSchema=True
)

display(df)

# write raw data as delta table
df.write.format("delta") \
.mode("overwrite") \
.save("/Volumes/workspace/default/my_volume_1/medallion/bronze")
